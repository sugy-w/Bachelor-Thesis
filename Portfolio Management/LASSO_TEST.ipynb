# %% [markdown]
# # **LASSO regression + Portfolio**
#
# Marek Šugár

# %%
import sys
import os

sys.path.append(os.path.abspath("../Model Kernels"))

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

from DataFramePrep import generate_TestDataFrame

from sklearn.preprocessing import StandardScaler

# ML Stuff
import cvxpy as cp
from sklearn.linear_model import Lasso

# %%
TrainingDataFrame, tickers, historic_columns, StockDataDatabase = generate_TestDataFrame()

# %%
def markowitz(predicted_returns, lambda_risk, cov_matrix):
    '''
    Markowitz portfolio optimization implementation using cvxpy.
    predicted_returns: np.array of predicted returns for each asset
    lambda_risk: risk aversion parameter
    returns: optimal weights for each asset
    '''
    w = cp.Variable(len(predicted_returns))

    objective = cp.Maximize(predicted_returns @ w - lambda_risk * cp.quad_form(w, cov_matrix))

    constraints = [cp.sum(w) == 1, w >= 0]

    problem = cp.Problem(objective, constraints)
    problem.solve()

    return w.value

# %%
def markowitz_with_tc(
    predicted_returns,
    cov_matrix,
    prev_weights,
    lambda_risk=20,
    lambda_tc=0.01
):
    """
    Markowitz optimization with transaction cost / turnover penalty.
    """

    n = len(predicted_returns)
    w = cp.Variable(n)

    objective = cp.Maximize(
        predicted_returns @ w
        - lambda_risk * cp.quad_form(w, cov_matrix)
        - lambda_tc * cp.norm1(w - prev_weights)
    )

    constraints = [
        cp.sum(w) == 1,
        w >= 0
    ]

    problem = cp.Problem(objective, constraints)
    problem.solve(solver=cp.OSQP)

    return w.value

# %%
def markowitz_clean(weights, threshold=1e-6):
    '''
    Cleans the weights by setting very small weights to zero and re-normalizing.
    weights: np.array of weights
    threshold: minimum weight to keep
    returns: cleaned weights
    '''
    weights_cleaned = np.where(weights < threshold, 0, weights)
    if np.sum(weights_cleaned) > 0:
        weights_cleaned /= np.sum(weights_cleaned)
    return weights_cleaned

# %%
Stock_Data = pd.read_sql(f"SELECT Ticker, Date, Close FROM StockData ORDER BY Ticker", con=StockDataDatabase, parse_dates=["Date"])

prices_frame = Stock_Data.pivot(index="Date", columns="Ticker", values="Close").sort_index().ffill()
historical_returns = prices_frame.pct_change().dropna()

# %% [markdown]
# # **RIDGE regression**

# %%
all_data = {}

for ticker in tickers["Ticker"]:
    df = pd.read_sql(
        f"SELECT * FROM StockData WHERE Ticker='{ticker}' AND Date>='2022-10-01'",
        con=StockDataDatabase,
        parse_dates=["Date"]
    )
    df = pd.merge(df, TrainingDataFrame, on="Date")
    df["Target"] = df["Close"]
    df = df.dropna().reset_index(drop=True)
    all_data[ticker] = df

# %%
training_length = 4 # This was optimized previously
prediction_length = 1

dates = all_data[tickers["Ticker"].iloc[0]]["Date"]

# %%
portfolio_predictions = {}

for t in range(len(dates) - (training_length + prediction_length)):

    current_date = dates.iloc[t + training_length]
    portfolio_predictions[current_date] = {}

    for ticker, Stock_Data in all_data.items():

        scaler = StandardScaler()

        X_train = scaler.fit_transform(
            Stock_Data[historic_columns].iloc[t:t+training_length]
        )
        y_train = Stock_Data["Target"].iloc[t:t+training_length]

        X_test = scaler.transform(
            Stock_Data[historic_columns].iloc[t+training_length:t+training_length+prediction_length]
        )

        model = Lasso(alpha=4.15, max_iter=3000) # This was optimized previously
        model.fit(X_train, y_train)

        prediction = model.predict(X_test)[0]

        pct_return = (prediction - Stock_Data["Close"].iloc[t+training_length-1]) / Stock_Data["Close"].iloc[t+training_length-1]

        portfolio_predictions[current_date][ticker] = pct_return

        print(f"Date: {current_date.date()}, Ticker: {ticker}, Prediction: {pct_return}")

# %% [markdown]
# For benchmarking, we do <code>pct_change()</code> for indices as well, we will benchmark to them.

# %%
snp = pd.read_sql("SELECT Date, Close FROM Indexes WHERE IndexName='S&P 500'", con=StockDataDatabase, parse_dates=["Date"])

snp["Return"] = snp["Close"].pct_change()

snp = snp.dropna()

# %%
nasdaq = pd.read_sql("SELECT Date, Close FROM Indexes WHERE IndexName='NASDAQ'", con=StockDataDatabase, parse_dates=["Date"])

nasdaq["Return"] = nasdaq["Close"].pct_change()
nasdaq = nasdaq.dropna()

# %%
def simulate_portfolio(
    lambda_risk=20,
    cov_window=60,
    lambda_tc=0.01,
    reportion=False
):
    '''
    Complete portfolio simulation with Markowitz optimization and transaction costs.
    lambda_risk: risk aversion parameter
    cov_window: window size for covariance matrix estimation
    lambda_tc: transaction cost penalty parameter
    reportion: if True, prints progress reports
    returns: portfolio values, benchmark values, weights history, turnover history
    '''
    initial_capital = 100

    capital = initial_capital
    capital_benchmark1 = initial_capital
    capital_benchmark2 = initial_capital

    portfolio_values = []
    snp_values = []
    nasdaq_values = []

    weights_history = []
    turnover_history = []

    t_start = 30

    # Explicit, no trading previously
    prev_weights = np.zeros(len(historical_returns.columns))

    for t in range(t_start, len(dates) - (training_length + prediction_length)):

        current_date = dates.iloc[t + training_length]

        # Covariance estimation
        covariance_data = historical_returns.loc[:current_date].tail(cov_window)
        cov_matrix = covariance_data.cov().values
        cov_matrix += 1e-6 * np.eye(cov_matrix.shape[0])

        # Predicted returns
        predicted_returns = np.array(
            list(portfolio_predictions[current_date].values())
        )

        # Portfolio optimization with turnover penalty
        optimal_weights = markowitz_clean(
            markowitz_with_tc(
                predicted_returns,
                cov_matrix=cov_matrix,
                prev_weights=prev_weights,
                lambda_risk=lambda_risk,
                lambda_tc=lambda_tc
            )
        )

        # Realized returns, based on next day after prediction
        next_day_index = t + training_length + prediction_length
        realized_r = historical_returns.iloc[next_day_index].values

        realized_bench = snp.iloc[next_day_index]["Return"]
        realized_nasdaq = nasdaq.iloc[next_day_index]["Return"]

        # Update portfolio values
        portfolio_return = np.dot(optimal_weights, realized_r)

        capital *= (1 + portfolio_return)
        capital_benchmark1 *= (1 + realized_bench)
        capital_benchmark2 *= (1 + realized_nasdaq)

        # Well, well, well...
        turnover = np.sum(np.abs(optimal_weights - prev_weights))

        portfolio_values.append(capital)
        snp_values.append(capital_benchmark1)
        nasdaq_values.append(capital_benchmark2)

        weights_history.append(optimal_weights)
        turnover_history.append(turnover)

        prev_weights = optimal_weights.copy()

        if reportion:
            print(
                f"Date: {current_date + pd.Timedelta(days=1)}, "
                f"Capital: {capital:.2f}, "
                f"Turnover: {turnover:.2f}"
            )

    return (
        np.array(portfolio_values),
        np.array(snp_values),
        np.array(nasdaq_values),
        np.array(weights_history),
        np.array(turnover_history),
    )

# %% [markdown]
# # **Compare various strategies**

# %%
# Some simulations with different risk aversion levels, to visually compare
conservative, snp_values, nasdaq_values, _, _  = simulate_portfolio(lambda_risk=1000, reportion=True)
# Out:
# Date: 2023-01-05 00:00:00, Capital: 99.55, Turnover: 1.00
# Date: 2023-01-06 00:00:00, Capital: 98.77, Turnover: 0.02
# Date: 2023-01-07 00:00:00, Capital: 99.00, Turnover: 0.14
# Date: 2023-01-10 00:00:00, Capital: 100.63, Turnover: 0.18
# Date: 2023-01-11 00:00:00, Capital: 100.88, Turnover: 0.40
# Date: 2023-01-12 00:00:00, Capital: 100.87, Turnover: 0.09
# Date: 2023-01-13 00:00:00, Capital: 100.87, Turnover: 0.11
# Date: 2023-01-14 00:00:00, Capital: 99.04, Turnover: 0.09
# Date: 2023-01-18 00:00:00, Capital: 99.13, Turnover: 0.05
# Date: 2023-01-19 00:00:00, Capital: 98.25, Turnover: 0.03
# Date: 2023-01-20 00:00:00, Capital: 98.18, Turnover: 0.30
# Date: 2023-01-21 00:00:00, Capital: 98.55, Turnover: 0.19
# Date: 2023-01-24 00:00:00, Capital: 97.72, Turnover: 0.08
# Date: 2023-01-25 00:00:00, Capital: 97.34, Turnover: 0.09
# Date: 2023-01-26 00:00:00, Capital: 96.90, Turnover: 0.00
# Date: 2023-01-27 00:00:00, Capital: 97.07, Turnover: 0.10
# Date: 2023-01-28 00:00:00, Capital: 96.29, Turnover: 0.06
# Date: 2023-01-31 00:00:00, Capital: 97.89, Turnover: 0.22
# Date: 2023-02-01 00:00:00, Capital: 97.38, Turnover: 0.08
# Date: 2023-02-02 00:00:00, Capital: 98.06, Turnover: 0.19
# Date: 2023-02-03 00:00:00, Capital: 98.32, Turnover: 0.15
# Date: 2023-02-04 00:00:00, Capital: 98.20, Turnover: 0.39
# Date: 2023-02-07 00:00:00, Capital: 98.72, Turnover: 0.20
# Date: 2023-02-08 00:00:00, Capital: 99.00, Turnover: 0.14
# Date: 2023-02-09 00:00:00, Capital: 99.82, Turnover: 0.76
# Date: 2023-02-10 00:00:00, Capital: 99.12, Turnover: 0.06
# Date: 2023-02-11 00:00:00, Capital: 99.43, Turnover: 0.14
# Date: 2023-02-14 00:00:00, Capital: 99.51, Turnover: 0.15
# Date: 2023-02-15 00:00:00, Capital: 99.24, Turnover: 0.01
# Date: 2023-02-16 00:00:00, Capital: 98.77, Turnover: 0.03
# Date: 2023-02-17 00:00:00, Capital: 98.42, Turnover: 0.04
# Date: 2023-02-18 00:00:00, Capital: 98.62, Turnover: 0.01
# Date: 2023-02-22 00:00:00, Capital: 99.23, Turnover: 0.12
# Date: 2023-02-23 00:00:00, Capital: 99.63, Turnover: 0.21
# Date: 2023-02-24 00:00:00, Capital: 99.84, Turnover: 0.04
# Date: 2023-02-25 00:00:00, Capital: 99.40, Turnover: 0.03
# Date: 2023-02-28 00:00:00, Capital: 99.11, Turnover: 0.03
# Date: 2023-03-01 00:00:00, Capital: 99.18, Turnover: 0.14
# Date: 2023-03-02 00:00:00, Capital: 100.38, Turnover: 0.00
# Date: 2023-03-03 00:00:00, Capital: 99.98, Turnover: 0.00
# Date: 2023-03-04 00:00:00, Capital: 100.10, Turnover: 0.13
# Date: 2023-03-07 00:00:00, Capital: 99.34, Turnover: 0.12
# Date: 2023-03-08 00:00:00, Capital: 99.42, Turnover: 0.09
# Date: 2023-03-09 00:00:00, Capital: 99.50, Turnover: 0.02
# Date: 2023-03-10 00:00:00, Capital: 99.67, Turnover: 0.05
# Date: 2023-03-11 00:00:00, Capital: 99.98, Turnover: 0.02
# Date: 2023-03-14 00:00:00, Capital: 99.20, Turnover: 0.10
# Date: 2023-03-15 00:00:00, Capital: 99.02, Turnover: 0.09
# Date: 2023-03-16 00:00:00, Capital: 100.66, Turnover: 0.74
# Date: 2023-03-17 00:00:00, Capital: 101.88, Turnover: 0.12
# Date: 2023-03-18 00:00:00, Capital: 102.83, Turnover: 0.04
# Date: 2023-03-21 00:00:00, Capital: 103.37, Turnover: 0.09
# Date: 2023-03-22 00:00:00, Capital: 103.43, Turnover: 0.01
# Date: 2023-03-23 00:00:00, Capital: 103.41, Turnover: 0.15
# Date: 2023-03-24 00:00:00, Capital: 103.97, Turnover: 0.01
# Date: 2023-03-25 00:00:00, Capital: 104.26, Turnover: 0.01
# Date: 2023-03-28 00:00:00, Capital: 103.68, Turnover: 0.08
# Date: 2023-03-29 00:00:00, Capital: 105.84, Turnover: 0.20
# Date: 2023-03-30 00:00:00, Capital: 106.12, Turnover: 0.26
# Date: 2023-03-31 00:00:00, Capital: 104.91, Turnover: 0.09
# Date: 2023-04-01 00:00:00, Capital: 104.99, Turnover: 0.12
# Date: 2023-04-04 00:00:00, Capital: 106.67, Turnover: 0.02
# Date: 2023-04-05 00:00:00, Capital: 106.51, Turnover: 0.03
# Date: 2023-04-06 00:00:00, Capital: 106.87, Turnover: 0.03
# Date: 2023-04-07 00:00:00, Capital: 108.30, Turnover: 0.07
# Date: 2023-04-11 00:00:00, Capital: 107.76, Turnover: 0.06
# Date: 2023-04-12 00:00:00, Capital: 106.52, Turnover: 0.02
# Date: 2023-04-13 00:00:00, Capital: 106.72, Turnover: 0.01
# Date: 2023-04-14 00:00:00, Capital: 107.04, Turnover: 0.06
# Date: 2023-04-15 00:00:00, Capital: 106.03, Turnover: 0.26
# Date: 2023-04-18 00:00:00, Capital: 100.99, Turnover: 0.07
# Date: 2023-04-19 00:00:00, Capital: 102.54, Turnover: 0.16
# Date: 2023-04-20 00:00:00, Capital: 102.07, Turnover: 0.08
# Date: 2023-04-21 00:00:00, Capital: 99.21, Turnover: 0.06
# Date: 2023-04-22 00:00:00, Capital: 100.21, Turnover: 0.66
# Date: 2023-04-25 00:00:00, Capital: 102.82, Turnover: 0.00
# Date: 2023-04-26 00:00:00, Capital: 102.98, Turnover: 0.27
# Date: 2023-04-27 00:00:00, Capital: 104.40, Turnover: 0.16
# Date: 2023-04-28 00:00:00, Capital: 106.02, Turnover: 0.38
# Date: 2023-04-29 00:00:00, Capital: 106.19, Turnover: 0.26
# Date: 2023-05-02 00:00:00, Capital: 106.23, Turnover: 0.41
# Date: 2023-05-03 00:00:00, Capital: 105.62, Turnover: 0.06
# Date: 2023-05-04 00:00:00, Capital: 105.68, Turnover: 0.41
# Date: 2023-05-05 00:00:00, Capital: 106.84, Turnover: 0.07
# Date: 2023-05-06 00:00:00, Capital: 108.76, Turnover: 0.22
# Date: 2023-05-09 00:00:00, Capital: 107.61, Turnover: 0.13
# Date: 2023-05-10 00:00:00, Capital: 106.68, Turnover: 0.22
# Date: 2023-05-11 00:00:00, Capital: 105.26, Turnover: 0.29
# Date: 2023-05-12 00:00:00, Capital: 106.12, Turnover: 0.20
# Date: 2023-05-13 00:00:00, Capital: 107.52, Turnover: 0.01
# Date: 2023-05-16 00:00:00, Capital: 107.40, Turnover: 0.09
# Date: 2023-05-17 00:00:00, Capital: 108.68, Turnover: 0.26
# Date: 2023-05-18 00:00:00, Capital: 108.61, Turnover: 0.06
# Date: 2023-05-19 00:00:00, Capital: 110.58, Turnover: 0.39
# Date: 2023-05-20 00:00:00, Capital: 110.77, Turnover: 0.08
# Date: 2023-05-23 00:00:00, Capital: 109.92, Turnover: 0.09
# Date: 2023-05-24 00:00:00, Capital: 109.68, Turnover: 0.12
# Date: 2023-05-25 00:00:00, Capital: 110.42, Turnover: 0.21
# Date: 2023-05-26 00:00:00, Capital: 110.67, Turnover: 0.09
# Date: 2023-05-27 00:00:00, Capital: 109.14, Turnover: 0.43
# Date: 2023-05-31 00:00:00, Capital: 109.64, Turnover: 0.37
# Date: 2023-06-01 00:00:00, Capital: 109.75, Turnover: 0.33
# Date: 2023-06-02 00:00:00, Capital: 106.77, Turnover: 0.25
# Date: 2023-06-03 00:00:00, Capital: 104.66, Turnover: 0.16
# Date: 2023-06-06 00:00:00, Capital: 107.99, Turnover: 0.09
# Date: 2023-06-07 00:00:00, Capital: 105.55, Turnover: 0.23
# Date: 2023-06-08 00:00:00, Capital: 105.03, Turnover: 0.22
# Date: 2023-06-09 00:00:00, Capital: 106.69, Turnover: 0.09
# Date: 2023-06-10 00:00:00, Capital: 104.24, Turnover: 0.07
# Date: 2023-06-13 00:00:00, Capital: 104.87, Turnover: 0.29
# Date: 2023-06-14 00:00:00, Capital: 106.72, Turnover: 0.38
# Date: 2023-06-15 00:00:00, Capital: 107.15, Turnover: 0.21
# Date: 2023-06-16 00:00:00, Capital: 104.70, Turnover: 0.21
# Date: 2023-06-17 00:00:00, Capital: 105.58, Turnover: 0.07
# Date: 2023-06-21 00:00:00, Capital: 107.72, Turnover: 0.18
# Date: 2023-06-22 00:00:00, Capital: 107.36, Turnover: 0.07
# Date: 2023-06-23 00:00:00, Capital: 109.00, Turnover: 0.16
# Date: 2023-06-24 00:00:00, Capital: 108.23, Turnover: 0.16
# Date: 2023-06-27 00:00:00, Capital: 109.04, Turnover: 0.01
# Date: 2023-06-28 00:00:00, Capital: 110.93, Turnover: 0.13
# Date: 2023-06-29 00:00:00, Capital: 107.84, Turnover: 0.20
# Date: 2023-06-30 00:00:00, Capital: 107.14, Turnover: 0.03
# Date: 2023-07-01 00:00:00, Capital: 105.84, Turnover: 0.06
# Date: 2023-07-04 00:00:00, Capital: 105.69, Turnover: 0.07
# Date: 2023-07-06 00:00:00, Capital: 104.22, Turnover: 0.00
# Date: 2023-07-07 00:00:00, Capital: 104.35, Turnover: 0.00
# Date: 2023-07-08 00:00:00, Capital: 105.07, Turnover: 0.01
# Date: 2023-07-11 00:00:00, Capital: 104.99, Turnover: 0.03
# Date: 2023-07-12 00:00:00, Capital: 104.41, Turnover: 0.04
# Date: 2023-07-13 00:00:00, Capital: 104.69, Turnover: 0.31
# Date: 2023-07-14 00:00:00, Capital: 104.38, Turnover: 0.18
# Date: 2023-07-15 00:00:00, Capital: 104.73, Turnover: 0.06
# Date: 2023-07-18 00:00:00, Capital: 106.16, Turnover: 0.14
# Date: 2023-07-19 00:00:00, Capital: 105.82, Turnover: 0.11
# Date: 2023-07-20 00:00:00, Capital: 105.88, Turnover: 0.11
# Date: 2023-07-21 00:00:00, Capital: 106.06, Turnover: 0.09
# Date: 2023-07-22 00:00:00, Capital: 107.28, Turnover: 0.51
# Date: 2023-07-25 00:00:00, Capital: 107.36, Turnover: 0.02
# Date: 2023-07-26 00:00:00, Capital: 106.90, Turnover: 0.21
# Date: 2023-07-27 00:00:00, Capital: 106.81, Turnover: 0.29
# Date: 2023-07-28 00:00:00, Capital: 106.77, Turnover: 0.05
# Date: 2023-07-29 00:00:00, Capital: 106.03, Turnover: 0.59
# Date: 2023-08-01 00:00:00, Capital: 106.12, Turnover: 0.36
# Date: 2023-08-02 00:00:00, Capital: 107.02, Turnover: 0.31
# Date: 2023-08-03 00:00:00, Capital: 107.01, Turnover: 0.10
# Date: 2023-08-04 00:00:00, Capital: 107.68, Turnover: 0.07
# Date: 2023-08-05 00:00:00, Capital: 107.76, Turnover: 0.51
# Date: 2023-08-08 00:00:00, Capital: 107.26, Turnover: 0.53
# Date: 2023-08-09 00:00:00, Capital: 106.31, Turnover: 0.07
# Date: 2023-08-10 00:00:00, Capital: 106.98, Turnover: 0.25
# Date: 2023-08-11 00:00:00, Capital: 105.63, Turnover: 0.62
# Date: 2023-08-12 00:00:00, Capital: 107.08, Turnover: 0.20
# Date: 2023-08-15 00:00:00, Capital: 107.83, Turnover: 0.08
# Date: 2023-08-16 00:00:00, Capital: 108.85, Turnover: 0.32
# Date: 2023-08-17 00:00:00, Capital: 109.45, Turnover: 0.02
# Date: 2023-08-18 00:00:00, Capital: 109.33, Turnover: 0.05
# Date: 2023-08-19 00:00:00, Capital: 109.74, Turnover: 0.12
# Date: 2023-08-22 00:00:00, Capital: 110.01, Turnover: 0.15
# Date: 2023-08-23 00:00:00, Capital: 110.72, Turnover: 0.08
# Date: 2023-08-24 00:00:00, Capital: 110.32, Turnover: 0.34
# Date: 2023-08-25 00:00:00, Capital: 110.26, Turnover: 0.52
# Date: 2023-08-26 00:00:00, Capital: 110.65, Turnover: 0.17
# Date: 2023-08-29 00:00:00, Capital: 110.81, Turnover: 0.19
# Date: 2023-08-30 00:00:00, Capital: 110.07, Turnover: 0.02
# Date: 2023-08-31 00:00:00, Capital: 109.98, Turnover: 0.29
# Date: 2023-09-01 00:00:00, Capital: 109.48, Turnover: 0.29
# Date: 2023-09-02 00:00:00, Capital: 109.18, Turnover: 0.39
# Date: 2023-09-06 00:00:00, Capital: 106.91, Turnover: 0.05
# Date: 2023-09-07 00:00:00, Capital: 107.04, Turnover: 0.08
# Date: 2023-09-08 00:00:00, Capital: 105.84, Turnover: 0.11
# Date: 2023-09-09 00:00:00, Capital: 106.50, Turnover: 1.49
# Date: 2023-09-12 00:00:00, Capital: 107.70, Turnover: 0.34
# Date: 2023-09-13 00:00:00, Capital: 107.96, Turnover: 0.26
# Date: 2023-09-14 00:00:00, Capital: 107.14, Turnover: 0.37
# Date: 2023-09-15 00:00:00, Capital: 108.40, Turnover: 0.14
# Date: 2023-09-16 00:00:00, Capital: 109.15, Turnover: 0.20
# Date: 2023-09-19 00:00:00, Capital: 110.52, Turnover: 0.09
# Date: 2023-09-20 00:00:00, Capital: 110.83, Turnover: 0.10
# Date: 2023-09-21 00:00:00, Capital: 110.36, Turnover: 0.13
# Date: 2023-09-22 00:00:00, Capital: 112.33, Turnover: 0.23
# Date: 2023-09-23 00:00:00, Capital: 112.36, Turnover: 0.10
# Date: 2023-09-26 00:00:00, Capital: 112.21, Turnover: 0.16
# Date: 2023-09-27 00:00:00, Capital: 112.56, Turnover: 0.15
# Date: 2023-09-28 00:00:00, Capital: 112.67, Turnover: 0.03
# Date: 2023-09-29 00:00:00, Capital: 113.15, Turnover: 0.00
# Date: 2023-09-30 00:00:00, Capital: 112.40, Turnover: 0.40
# Date: 2023-10-03 00:00:00, Capital: 112.20, Turnover: 0.01
# Date: 2023-10-04 00:00:00, Capital: 112.23, Turnover: 0.10
# Date: 2023-10-05 00:00:00, Capital: 113.80, Turnover: 0.15
# Date: 2023-10-06 00:00:00, Capital: 114.58, Turnover: 0.01
# Date: 2023-10-07 00:00:00, Capital: 113.11, Turnover: 0.07
# Date: 2023-10-10 00:00:00, Capital: 111.54, Turnover: 0.12
# Date: 2023-10-11 00:00:00, Capital: 111.80, Turnover: 0.14
# Date: 2023-10-12 00:00:00, Capital: 111.89, Turnover: 0.02
# Date: 2023-10-13 00:00:00, Capital: 112.49, Turnover: 0.04
# Date: 2023-10-14 00:00:00, Capital: 114.00, Turnover: 0.27
# Date: 2023-10-17 00:00:00, Capital: 114.20, Turnover: 0.04
# Date: 2023-10-18 00:00:00, Capital: 114.69, Turnover: 0.09
# Date: 2023-10-19 00:00:00, Capital: 114.90, Turnover: 0.03
# Date: 2023-10-20 00:00:00, Capital: 114.79, Turnover: 0.06
# Date: 2023-10-21 00:00:00, Capital: 114.34, Turnover: 0.26
# Date: 2023-10-24 00:00:00, Capital: 113.27, Turnover: 0.51
# Date: 2023-10-25 00:00:00, Capital: 114.50, Turnover: 0.22
# Date: 2023-10-26 00:00:00, Capital: 113.87, Turnover: 0.02
# Date: 2023-10-27 00:00:00, Capital: 113.78, Turnover: 0.39
# Date: 2023-10-28 00:00:00, Capital: 114.90, Turnover: 0.31
# Date: 2023-10-31 00:00:00, Capital: 115.73, Turnover: 0.27
# Date: 2023-11-01 00:00:00, Capital: 115.62, Turnover: 0.35
# Date: 2023-11-02 00:00:00, Capital: 116.26, Turnover: 0.11
# Date: 2023-11-03 00:00:00, Capital: 116.56, Turnover: 0.92
# Date: 2023-11-04 00:00:00, Capital: 117.51, Turnover: 0.52
# Date: 2023-11-07 00:00:00, Capital: 118.16, Turnover: 0.97
# Date: 2023-11-08 00:00:00, Capital: 119.06, Turnover: 0.44
# Date: 2023-11-09 00:00:00, Capital: 120.37, Turnover: 0.97
# Date: 2023-11-10 00:00:00, Capital: 119.72, Turnover: 0.16
# Date: 2023-11-11 00:00:00, Capital: 120.66, Turnover: 0.25
# Date: 2023-11-14 00:00:00, Capital: 119.92, Turnover: 0.10
# Date: 2023-11-15 00:00:00, Capital: 118.71, Turnover: 0.19
# Date: 2023-11-16 00:00:00, Capital: 119.32, Turnover: 0.19
# Date: 2023-11-17 00:00:00, Capital: 119.20, Turnover: 0.24
# Date: 2023-11-18 00:00:00, Capital: 120.38, Turnover: 0.69
# Date: 2023-11-21 00:00:00, Capital: 121.22, Turnover: 0.05
# Date: 2023-11-22 00:00:00, Capital: 121.21, Turnover: 0.14
# Date: 2023-11-23 00:00:00, Capital: 122.53, Turnover: 0.27
# Date: 2023-11-25 00:00:00, Capital: 122.39, Turnover: 0.36
# Date: 2023-11-28 00:00:00, Capital: 121.15, Turnover: 0.19
# Date: 2023-11-29 00:00:00, Capital: 121.55, Turnover: 0.25
# Date: 2023-11-30 00:00:00, Capital: 120.39, Turnover: 0.31
# Date: 2023-12-01 00:00:00, Capital: 121.55, Turnover: 0.03
# Date: 2023-12-02 00:00:00, Capital: 121.59, Turnover: 0.48
# Date: 2023-12-05 00:00:00, Capital: 121.35, Turnover: 0.30
# Date: 2023-12-06 00:00:00, Capital: 121.47, Turnover: 0.12
# Date: 2023-12-07 00:00:00, Capital: 121.17, Turnover: 0.12
# Date: 2023-12-08 00:00:00, Capital: 121.40, Turnover: 0.03
# Date: 2023-12-09 00:00:00, Capital: 122.03, Turnover: 0.19
# Date: 2023-12-12 00:00:00, Capital: 122.03, Turnover: 0.13
# Date: 2023-12-13 00:00:00, Capital: 121.31, Turnover: 0.11
# Date: 2023-12-14 00:00:00, Capital: 121.64, Turnover: 0.11
# Date: 2023-12-15 00:00:00, Capital: 119.08, Turnover: 0.15
# Date: 2023-12-16 00:00:00, Capital: 117.71, Turnover: 0.52
# Date: 2023-12-19 00:00:00, Capital: 116.38, Turnover: 0.10
# Date: 2023-12-20 00:00:00, Capital: 115.83, Turnover: 0.69
# Date: 2023-12-21 00:00:00, Capital: 111.54, Turnover: 0.71
# Date: 2023-12-22 00:00:00, Capital: 109.78, Turnover: 0.86
# Date: 2023-12-23 00:00:00, Capital: 112.37, Turnover: 0.41
# Date: 2023-12-27 00:00:00, Capital: 111.28, Turnover: 0.65
# Date: 2023-12-28 00:00:00, Capital: 114.44, Turnover: 0.75
# Date: 2023-12-29 00:00:00, Capital: 111.93, Turnover: 0.04
# Date: 2023-12-30 00:00:00, Capital: 109.77, Turnover: 0.01
# Date: 2024-01-03 00:00:00, Capital: 109.34, Turnover: 0.06
# Date: 2024-01-04 00:00:00, Capital: 110.34, Turnover: 0.18
# Date: 2024-01-05 00:00:00, Capital: 109.82, Turnover: 0.27
# Date: 2024-01-06 00:00:00, Capital: 106.07, Turnover: 0.05
# Date: 2024-01-09 00:00:00, Capital: 107.87, Turnover: 0.02
# Date: 2024-01-10 00:00:00, Capital: 107.44, Turnover: 0.09
# Date: 2024-01-11 00:00:00, Capital: 105.10, Turnover: 0.17
# Date: 2024-01-12 00:00:00, Capital: 108.84, Turnover: 0.22
# Date: 2024-01-13 00:00:00, Capital: 110.06, Turnover: 0.03
# Date: 2024-01-17 00:00:00, Capital: 110.73, Turnover: 0.24
# Date: 2024-01-18 00:00:00, Capital: 110.03, Turnover: 0.17
# Date: 2024-01-19 00:00:00, Capital: 109.98, Turnover: 0.08
# Date: 2024-01-20 00:00:00, Capital: 111.43, Turnover: 0.31
# Date: 2024-01-23 00:00:00, Capital: 114.27, Turnover: 0.32
# Date: 2024-01-24 00:00:00, Capital: 114.40, Turnover: 0.05
# Date: 2024-01-25 00:00:00, Capital: 112.85, Turnover: 0.12
# Date: 2024-01-26 00:00:00, Capital: 109.67, Turnover: 0.41
# Date: 2024-01-27 00:00:00, Capital: 109.76, Turnover: 0.21
# Date: 2024-01-30 00:00:00, Capital: 108.70, Turnover: 0.05
# Date: 2024-01-31 00:00:00, Capital: 110.37, Turnover: 0.67
# Date: 2024-02-01 00:00:00, Capital: 111.16, Turnover: 0.08
# Date: 2024-02-02 00:00:00, Capital: 108.45, Turnover: 0.41
# Date: 2024-02-03 00:00:00, Capital: 106.22, Turnover: 0.31
# Date: 2024-02-06 00:00:00, Capital: 107.46, Turnover: 1.57
# Date: 2024-02-07 00:00:00, Capital: 107.68, Turnover: 1.31
# Date: 2024-02-08 00:00:00, Capital: 109.31, Turnover: 0.11
# Date: 2024-02-09 00:00:00, Capital: 109.10, Turnover: 0.16
# Date: 2024-02-10 00:00:00, Capital: 111.93, Turnover: 0.04
# Date: 2024-02-13 00:00:00, Capital: 110.71, Turnover: 0.36
# Date: 2024-02-14 00:00:00, Capital: 111.07, Turnover: 0.45
# Date: 2024-02-15 00:00:00, Capital: 113.25, Turnover: 0.34
# Date: 2024-02-16 00:00:00, Capital: 110.01, Turnover: 0.16
# Date: 2024-02-17 00:00:00, Capital: 109.96, Turnover: 0.38
# Date: 2024-02-21 00:00:00, Capital: 107.42, Turnover: 0.20
# Date: 2024-02-22 00:00:00, Capital: 108.70, Turnover: 0.54
# Date: 2024-02-23 00:00:00, Capital: 108.40, Turnover: 0.86
# Date: 2024-02-24 00:00:00, Capital: 109.64, Turnover: 0.46
# Date: 2024-02-27 00:00:00, Capital: 109.48, Turnover: 0.52
# Date: 2024-02-28 00:00:00, Capital: 106.71, Turnover: 0.51
# Date: 2024-02-29 00:00:00, Capital: 103.96, Turnover: 0.54
# Date: 2024-03-01 00:00:00, Capital: 103.85, Turnover: 0.05
# Date: 2024-03-02 00:00:00, Capital: 102.01, Turnover: 0.15
# Date: 2024-03-05 00:00:00, Capital: 100.02, Turnover: 0.18
# Date: 2024-03-06 00:00:00, Capital: 97.25, Turnover: 0.27
# Date: 2024-03-07 00:00:00, Capital: 94.72, Turnover: 0.51
# Date: 2024-03-08 00:00:00, Capital: 99.20, Turnover: 0.12
# Date: 2024-03-09 00:00:00, Capital: 100.23, Turnover: 0.37
# Date: 2024-03-12 00:00:00, Capital: 99.96, Turnover: 0.04
# Date: 2024-03-13 00:00:00, Capital: 102.45, Turnover: 1.24
# Date: 2024-03-14 00:00:00, Capital: 101.47, Turnover: 1.24
# Date: 2024-03-15 00:00:00, Capital: 98.14, Turnover: 0.00
# Date: 2024-03-16 00:00:00, Capital: 102.38, Turnover: 0.10
# Date: 2024-03-19 00:00:00, Capital: 103.66, Turnover: 0.05
# Date: 2024-03-20 00:00:00, Capital: 105.36, Turnover: 0.49
# Date: 2024-03-21 00:00:00, Capital: 104.86, Turnover: 0.09
# Date: 2024-03-22 00:00:00, Capital: 105.81, Turnover: 1.69
# Date: 2024-03-23 00:00:00, Capital: 105.94, Turnover: 1.53
# Date: 2024-03-26 00:00:00, Capital: 105.16, Turnover: 0.13
# Date: 2024-03-27 00:00:00, Capital: 106.97, Turnover: 0.24
# Date: 2024-03-28 00:00:00, Capital: 107.22, Turnover: 0.21
# Date: 2024-03-29 00:00:00, Capital: 108.09, Turnover: 0.17
# Date: 2024-04-02 00:00:00, Capital: 109.68, Turnover: 0.21
# Date: 2024-04-03 00:00:00, Capital: 108.17, Turnover: 0.09
# Date: 2024-04-04 00:00:00, Capital: 109.10, Turnover: 0.10
# Date: 2024-04-05 00:00:00, Capital: 110.08, Turnover: 0.14
# Date: 2024-04-06 00:00:00, Capital: 111.90, Turnover: 0.08
# Date: 2024-04-09 00:00:00, Capital: 111.06, Turnover: 0.09
# Date: 2024-04-10 00:00:00, Capital: 110.67, Turnover: 0.10
# Date: 2024-04-11 00:00:00, Capital: 113.24, Turnover: 0.21
# Date: 2024-04-12 00:00:00, Capital: 114.17, Turnover: 0.11
# Date: 2024-04-13 00:00:00, Capital: 115.42, Turnover: 0.37
# Date: 2024-04-16 00:00:00, Capital: 116.85, Turnover: 0.14
# Date: 2024-04-17 00:00:00, Capital: 117.68, Turnover: 0.11
# Date: 2024-04-18 00:00:00, Capital: 118.32, Turnover: 0.09
# Date: 2024-04-19 00:00:00, Capital: 117.14, Turnover: 0.04
# Date: 2024-04-20 00:00:00, Capital: 117.67, Turnover: 0.22
# Date: 2024-04-23 00:00:00, Capital: 117.38, Turnover: 0.30
# Date: 2024-04-24 00:00:00, Capital: 119.09, Turnover: 0.66
# Date: 2024-04-25 00:00:00, Capital: 118.96, Turnover: 0.65
# Date: 2024-04-26 00:00:00, Capital: 118.86, Turnover: 0.96
# Date: 2024-04-27 00:00:00, Capital: 119.55, Turnover: 1.06
# Date: 2024-04-30 00:00:00, Capital: 119.70, Turnover: 0.55
# Date: 2024-05-01 00:00:00, Capital: 119.66, Turnover: 1.15
# Date: 2024-05-02 00:00:00, Capital: 120.52, Turnover: 0.35
# Date: 2024-05-03 00:00:00, Capital: 121.58, Turnover: 0.56
# Date: 2024-05-04 00:00:00, Capital: 122.20, Turnover: 0.55
# Date: 2024-05-07 00:00:00, Capital: 122.12, Turnover: 0.60
# Date: 2024-05-08 00:00:00, Capital: 122.17, Turnover: 0.18
# Date: 2024-05-09 00:00:00, Capital: 121.79, Turnover: 0.14
# Date: 2024-05-10 00:00:00, Capital: 122.20, Turnover: 0.24
# Date: 2024-05-11 00:00:00, Capital: 120.53, Turnover: 0.33
# Date: 2024-05-14 00:00:00, Capital: 120.62, Turnover: 0.37
# Date: 2024-05-15 00:00:00, Capital: 120.12, Turnover: 0.30
# Date: 2024-05-16 00:00:00, Capital: 119.35, Turnover: 0.39
# Date: 2024-05-17 00:00:00, Capital: 119.17, Turnover: 0.11
# Date: 2024-05-18 00:00:00, Capital: 120.99, Turnover: 0.21
# Date: 2024-05-21 00:00:00, Capital: 121.26, Turnover: 0.31
# Date: 2024-05-22 00:00:00, Capital: 121.66, Turnover: 0.05
# Date: 2024-05-23 00:00:00, Capital: 121.95, Turnover: 0.36
# Date: 2024-05-24 00:00:00, Capital: 122.67, Turnover: 0.04
# Date: 2024-05-25 00:00:00, Capital: 123.20, Turnover: 0.17
# Date: 2024-05-29 00:00:00, Capital: 123.51, Turnover: 0.56
# Date: 2024-05-30 00:00:00, Capital: 123.20, Turnover: 0.57
# Date: 2024-05-31 00:00:00, Capital: 125.59, Turnover: 0.06
# Date: 2024-06-01 00:00:00, Capital: 122.31, Turnover: 0.12
# Date: 2024-06-04 00:00:00, Capital: 121.54, Turnover: 0.66
# Date: 2024-06-05 00:00:00, Capital: 122.62, Turnover: 0.42
# Date: 2024-06-06 00:00:00, Capital: 121.77, Turnover: 0.25
# Date: 2024-06-07 00:00:00, Capital: 122.36, Turnover: 0.48
# Date: 2024-06-08 00:00:00, Capital: 123.35, Turnover: 0.04
# Date: 2024-06-11 00:00:00, Capital: 125.59, Turnover: 0.16
# Date: 2024-06-12 00:00:00, Capital: 125.74, Turnover: 0.34
# Date: 2024-06-13 00:00:00, Capital: 126.51, Turnover: 0.43
# Date: 2024-06-14 00:00:00, Capital: 125.85, Turnover: 0.39
# Date: 2024-06-15 00:00:00, Capital: 126.42, Turnover: 0.36
# Date: 2024-06-18 00:00:00, Capital: 126.89, Turnover: 0.33
# Date: 2024-06-19 00:00:00, Capital: 126.15, Turnover: 0.28
# Date: 2024-06-21 00:00:00, Capital: 127.43, Turnover: 0.77
# Date: 2024-06-22 00:00:00, Capital: 128.20, Turnover: 0.65
# Date: 2024-06-25 00:00:00, Capital: 129.68, Turnover: 0.09
# Date: 2024-06-26 00:00:00, Capital: 129.78, Turnover: 1.94
# Date: 2024-06-27 00:00:00, Capital: 129.84, Turnover: 1.73
# Date: 2024-06-28 00:00:00, Capital: 128.83, Turnover: 0.34
# Date: 2024-06-29 00:00:00, Capital: 129.00, Turnover: 0.06
# Date: 2024-07-02 00:00:00, Capital: 128.71, Turnover: 0.09
# Date: 2024-07-03 00:00:00, Capital: 130.11, Turnover: 0.16
# Date: 2024-07-04 00:00:00, Capital: 129.85, Turnover: 0.03
# Date: 2024-07-06 00:00:00, Capital: 128.79, Turnover: 0.05
# Date: 2024-07-09 00:00:00, Capital: 130.05, Turnover: 0.20
# Date: 2024-07-10 00:00:00, Capital: 130.12, Turnover: 0.12
# Date: 2024-07-11 00:00:00, Capital: 128.95, Turnover: 0.24
# Date: 2024-07-12 00:00:00, Capital: 128.29, Turnover: 0.22
# Date: 2024-07-13 00:00:00, Capital: 127.65, Turnover: 0.28
# Date: 2024-07-16 00:00:00, Capital: 128.03, Turnover: 0.39
# Date: 2024-07-17 00:00:00, Capital: 127.37, Turnover: 0.09
# Date: 2024-07-18 00:00:00, Capital: 124.71, Turnover: 0.08
# Date: 2024-07-19 00:00:00, Capital: 124.59, Turnover: 0.48
# Date: 2024-07-20 00:00:00, Capital: 123.71, Turnover: 0.31
# Date: 2024-07-23 00:00:00, Capital: 124.19, Turnover: 0.38
# Date: 2024-07-24 00:00:00, Capital: 119.20, Turnover: 0.46
# Date: 2024-07-25 00:00:00, Capital: 121.49, Turnover: 1.66
# Date: 2024-07-26 00:00:00, Capital: 122.68, Turnover: 1.17
# Date: 2024-07-27 00:00:00, Capital: 125.45, Turnover: 1.12
# Date: 2024-07-30 00:00:00, Capital: 124.24, Turnover: 1.20
# Date: 2024-07-31 00:00:00, Capital: 123.24, Turnover: 1.06
# Date: 2024-08-01 00:00:00, Capital: 125.46, Turnover: 0.47
# Date: 2024-08-02 00:00:00, Capital: 124.97, Turnover: 0.40
# Date: 2024-08-03 00:00:00, Capital: 121.65, Turnover: 0.76
# Date: 2024-08-06 00:00:00, Capital: 121.86, Turnover: 1.74
# Date: 2024-08-07 00:00:00, Capital: 121.34, Turnover: 1.67
# Date: 2024-08-08 00:00:00, Capital: 120.28, Turnover: 0.82
# Date: 2024-08-09 00:00:00, Capital: 120.91, Turnover: 0.91
# Date: 2024-08-10 00:00:00, Capital: 118.82, Turnover: 0.82
# Date: 2024-08-13 00:00:00, Capital: 116.62, Turnover: 0.89
# Date: 2024-08-14 00:00:00, Capital: 119.93, Turnover: 0.95
# Date: 2024-08-15 00:00:00, Capital: 122.36, Turnover: 0.73
# Date: 2024-08-16 00:00:00, Capital: 123.37, Turnover: 0.24
# Date: 2024-08-17 00:00:00, Capital: 124.99, Turnover: 0.06
# Date: 2024-08-20 00:00:00, Capital: 125.29, Turnover: 0.09
# Date: 2024-08-21 00:00:00, Capital: 124.72, Turnover: 0.24
# Date: 2024-08-22 00:00:00, Capital: 125.04, Turnover: 0.05
# Date: 2024-08-23 00:00:00, Capital: 124.89, Turnover: 0.09
# Date: 2024-08-24 00:00:00, Capital: 124.63, Turnover: 0.18
# Date: 2024-08-27 00:00:00, Capital: 125.41, Turnover: 0.29
# Date: 2024-08-28 00:00:00, Capital: 126.81, Turnover: 0.32
# Date: 2024-08-29 00:00:00, Capital: 128.10, Turnover: 0.20
# Date: 2024-08-30 00:00:00, Capital: 129.25, Turnover: 0.02
# Date: 2024-08-31 00:00:00, Capital: 128.77, Turnover: 0.33
# Date: 2024-09-04 00:00:00, Capital: 128.96, Turnover: 0.13
# Date: 2024-09-05 00:00:00, Capital: 127.52, Turnover: 0.62
# Date: 2024-09-06 00:00:00, Capital: 127.63, Turnover: 0.40
# Date: 2024-09-07 00:00:00, Capital: 128.21, Turnover: 0.36
# Date: 2024-09-10 00:00:00, Capital: 129.70, Turnover: 0.32
# Date: 2024-09-11 00:00:00, Capital: 130.65, Turnover: 0.21
# Date: 2024-09-12 00:00:00, Capital: 131.60, Turnover: 0.17
# Date: 2024-09-13 00:00:00, Capital: 132.90, Turnover: 0.24
# Date: 2024-09-14 00:00:00, Capital: 133.04, Turnover: 0.09
# Date: 2024-09-17 00:00:00, Capital: 131.93, Turnover: 0.07
# Date: 2024-09-18 00:00:00, Capital: 132.87, Turnover: 0.02
# Date: 2024-09-19 00:00:00, Capital: 133.15, Turnover: 0.14
# Date: 2024-09-20 00:00:00, Capital: 133.75, Turnover: 0.03
# Date: 2024-09-21 00:00:00, Capital: 135.03, Turnover: 0.12
# Date: 2024-09-24 00:00:00, Capital: 135.21, Turnover: 0.05
# Date: 2024-09-25 00:00:00, Capital: 134.38, Turnover: 0.44
# Date: 2024-09-26 00:00:00, Capital: 133.67, Turnover: 0.25
# Date: 2024-09-27 00:00:00, Capital: 134.25, Turnover: 0.02
# Date: 2024-09-28 00:00:00, Capital: 133.12, Turnover: 0.57
# Date: 2024-10-01 00:00:00, Capital: 134.01, Turnover: 0.29
# Date: 2024-10-02 00:00:00, Capital: 134.36, Turnover: 0.24
# Date: 2024-10-03 00:00:00, Capital: 135.48, Turnover: 0.30
# Date: 2024-10-04 00:00:00, Capital: 135.68, Turnover: 0.31
# Date: 2024-10-05 00:00:00, Capital: 136.64, Turnover: 0.03
# Date: 2024-10-08 00:00:00, Capital: 135.98, Turnover: 0.09
# Date: 2024-10-09 00:00:00, Capital: 135.10, Turnover: 0.09
# Date: 2024-10-10 00:00:00, Capital: 134.97, Turnover: 0.28
# Date: 2024-10-11 00:00:00, Capital: 135.81, Turnover: 0.07
# Date: 2024-10-12 00:00:00, Capital: 136.93, Turnover: 0.08
# Date: 2024-10-15 00:00:00, Capital: 133.28, Turnover: 0.05
# Date: 2024-10-16 00:00:00, Capital: 135.91, Turnover: 0.03
# Date: 2024-10-17 00:00:00, Capital: 137.61, Turnover: 0.13
# Date: 2024-10-18 00:00:00, Capital: 141.26, Turnover: 0.02
# Date: 2024-10-19 00:00:00, Capital: 139.83, Turnover: 0.20
# Date: 2024-10-22 00:00:00, Capital: 137.92, Turnover: 0.33
# Date: 2024-10-23 00:00:00, Capital: 140.04, Turnover: 0.19
# Date: 2024-10-24 00:00:00, Capital: 136.36, Turnover: 0.12
# Date: 2024-10-25 00:00:00, Capital: 137.26, Turnover: 0.59
# Date: 2024-10-26 00:00:00, Capital: 139.09, Turnover: 0.24
# Date: 2024-10-29 00:00:00, Capital: 140.95, Turnover: 0.04
# Date: 2024-10-30 00:00:00, Capital: 140.17, Turnover: 0.64
# Date: 2024-10-31 00:00:00, Capital: 141.94, Turnover: 0.10
# Date: 2024-11-01 00:00:00, Capital: 141.44, Turnover: 0.39
# Date: 2024-11-02 00:00:00, Capital: 138.57, Turnover: 0.31
# Date: 2024-11-05 00:00:00, Capital: 140.45, Turnover: 0.68
# Date: 2024-11-06 00:00:00, Capital: 140.39, Turnover: 1.89
# Date: 2024-11-07 00:00:00, Capital: 140.19, Turnover: 1.22
# Date: 2024-11-08 00:00:00, Capital: 141.52, Turnover: 0.52
# Date: 2024-11-09 00:00:00, Capital: 140.96, Turnover: 0.28
# Date: 2024-11-12 00:00:00, Capital: 138.86, Turnover: 0.65
# Date: 2024-11-13 00:00:00, Capital: 140.25, Turnover: 1.06
# Date: 2024-11-14 00:00:00, Capital: 140.63, Turnover: 0.61
# Date: 2024-11-15 00:00:00, Capital: 141.02, Turnover: 0.55
# Date: 2024-11-16 00:00:00, Capital: 139.66, Turnover: 0.90
# Date: 2024-11-19 00:00:00, Capital: 138.31, Turnover: 0.58
# Date: 2024-11-20 00:00:00, Capital: 140.10, Turnover: 1.47
# Date: 2024-11-21 00:00:00, Capital: 140.18, Turnover: 1.36
# Date: 2024-11-22 00:00:00, Capital: 139.79, Turnover: 0.13
# Date: 2024-11-23 00:00:00, Capital: 139.98, Turnover: 0.18
# Date: 2024-11-26 00:00:00, Capital: 140.83, Turnover: 0.09
# Date: 2024-11-27 00:00:00, Capital: 140.62, Turnover: 0.23
# Date: 2024-11-28 00:00:00, Capital: 140.30, Turnover: 0.37
# Date: 2024-11-30 00:00:00, Capital: 139.61, Turnover: 0.26
# Date: 2024-12-03 00:00:00, Capital: 139.92, Turnover: 0.15
# Date: 2024-12-04 00:00:00, Capital: 138.71, Turnover: 0.20
# Date: 2024-12-05 00:00:00, Capital: 140.88, Turnover: 0.16
# Date: 2024-12-06 00:00:00, Capital: 139.86, Turnover: 0.19
# Date: 2024-12-07 00:00:00, Capital: 138.14, Turnover: 0.03
# Date: 2024-12-10 00:00:00, Capital: 139.43, Turnover: 0.09
# Date: 2024-12-11 00:00:00, Capital: 137.06, Turnover: 0.16
# Date: 2024-12-12 00:00:00, Capital: 135.26, Turnover: 0.16
# Date: 2024-12-13 00:00:00, Capital: 136.45, Turnover: 0.21
# Date: 2024-12-14 00:00:00, Capital: 138.66, Turnover: 0.19
# Date: 2024-12-17 00:00:00, Capital: 138.27, Turnover: 0.17
# Date: 2024-12-18 00:00:00, Capital: 136.35, Turnover: 0.12
# Date: 2024-12-19 00:00:00, Capital: 137.93, Turnover: 0.21
# Date: 2024-12-20 00:00:00, Capital: 138.35, Turnover: 0.45
# Date: 2024-12-21 00:00:00, Capital: 138.89, Turnover: 0.59
# Date: 2024-12-24 00:00:00, Capital: 138.94, Turnover: 0.17
# Date: 2024-12-25 00:00:00, Capital: 139.92, Turnover: 0.21
# Date: 2024-12-27 00:00:00, Capital: 139.43, Turnover: 0.22
# Date: 2024-12-28 00:00:00, Capital: 139.92, Turnover: 0.01
# Date: 2024-12-31 00:00:00, Capital: 139.31, Turnover: 0.04
# Date: 2025-01-01 00:00:00, Capital: 140.93, Turnover: 0.21
# Date: 2025-01-03 00:00:00, Capital: 139.50, Turnover: 0.00
# Date: 2025-01-04 00:00:00, Capital: 140.66, Turnover: 0.10
# Date: 2025-01-07 00:00:00, Capital: 140.57, Turnover: 0.12
# Date: 2025-01-08 00:00:00, Capital: 140.39, Turnover: 0.05
# Date: 2025-01-09 00:00:00, Capital: 141.15, Turnover: 0.08
# Date: 2025-01-11 00:00:00, Capital: 140.97, Turnover: 0.23
# Date: 2025-01-14 00:00:00, Capital: 141.33, Turnover: 0.13
# Date: 2025-01-15 00:00:00, Capital: 141.20, Turnover: 0.07
# Date: 2025-01-16 00:00:00, Capital: 142.99, Turnover: 0.05
# Date: 2025-01-17 00:00:00, Capital: 143.28, Turnover: 0.06
# Date: 2025-01-18 00:00:00, Capital: 143.35, Turnover: 0.16
# Date: 2025-01-22 00:00:00, Capital: 143.99, Turnover: 0.02
# Date: 2025-01-23 00:00:00, Capital: 144.87, Turnover: 0.27
# Date: 2025-01-24 00:00:00, Capital: 145.57, Turnover: 0.17
# Date: 2025-01-25 00:00:00, Capital: 144.88, Turnover: 0.04
# Date: 2025-01-28 00:00:00, Capital: 144.84, Turnover: 0.25
# Date: 2025-01-29 00:00:00, Capital: 145.48, Turnover: 0.91
# Date: 2025-01-30 00:00:00, Capital: 145.37, Turnover: 0.54
# Date: 2025-01-31 00:00:00, Capital: 146.04, Turnover: 0.42
# Date: 2025-02-01 00:00:00, Capital: 145.94, Turnover: 0.29
# Date: 2025-02-04 00:00:00, Capital: 148.10, Turnover: 0.23
# Date: 2025-02-05 00:00:00, Capital: 148.01, Turnover: 0.09
# Date: 2025-02-06 00:00:00, Capital: 147.22, Turnover: 0.18
# Date: 2025-02-07 00:00:00, Capital: 147.14, Turnover: 0.42
# Date: 2025-02-08 00:00:00, Capital: 148.14, Turnover: 0.45
# Date: 2025-02-11 00:00:00, Capital: 148.42, Turnover: 0.24
# Date: 2025-02-12 00:00:00, Capital: 149.24, Turnover: 0.20
# Date: 2025-02-13 00:00:00, Capital: 148.79, Turnover: 0.07
# Date: 2025-02-14 00:00:00, Capital: 146.87, Turnover: 0.04
# Date: 2025-02-15 00:00:00, Capital: 146.15, Turnover: 0.18
# Date: 2025-02-19 00:00:00, Capital: 146.61, Turnover: 0.42
# Date: 2025-02-20 00:00:00, Capital: 144.90, Turnover: 0.26
# Date: 2025-02-21 00:00:00, Capital: 146.32, Turnover: 0.39
# Date: 2025-02-22 00:00:00, Capital: 145.80, Turnover: 0.60
# Date: 2025-02-25 00:00:00, Capital: 145.94, Turnover: 0.25
# Date: 2025-02-26 00:00:00, Capital: 147.42, Turnover: 0.56
# Date: 2025-02-27 00:00:00, Capital: 149.03, Turnover: 0.37
# Date: 2025-02-28 00:00:00, Capital: 149.06, Turnover: 0.51
# Date: 2025-03-01 00:00:00, Capital: 150.41, Turnover: 0.53
# Date: 2025-03-04 00:00:00, Capital: 149.84, Turnover: 0.87
# Date: 2025-03-05 00:00:00, Capital: 149.18, Turnover: 1.40
# Date: 2025-03-06 00:00:00, Capital: 150.28, Turnover: 1.01
# Date: 2025-03-07 00:00:00, Capital: 151.15, Turnover: 0.15
# Date: 2025-03-08 00:00:00, Capital: 151.28, Turnover: 0.11
# Date: 2025-03-11 00:00:00, Capital: 151.20, Turnover: 0.32
# Date: 2025-03-12 00:00:00, Capital: 151.52, Turnover: 0.26
# Date: 2025-03-13 00:00:00, Capital: 151.42, Turnover: 0.76
# Date: 2025-03-14 00:00:00, Capital: 150.66, Turnover: 0.37
# Date: 2025-03-15 00:00:00, Capital: 150.88, Turnover: 0.24
# Date: 2025-03-18 00:00:00, Capital: 153.62, Turnover: 0.18
# Date: 2025-03-19 00:00:00, Capital: 154.18, Turnover: 0.14
# Date: 2025-03-20 00:00:00, Capital: 154.26, Turnover: 0.25
# Date: 2025-03-21 00:00:00, Capital: 154.09, Turnover: 0.16
# Date: 2025-03-22 00:00:00, Capital: 154.96, Turnover: 0.14
# Date: 2025-03-25 00:00:00, Capital: 156.92, Turnover: 0.05
# Date: 2025-03-26 00:00:00, Capital: 156.67, Turnover: 0.06
# Date: 2025-03-27 00:00:00, Capital: 158.58, Turnover: 0.18
# Date: 2025-03-28 00:00:00, Capital: 158.04, Turnover: 0.31
# Date: 2025-03-29 00:00:00, Capital: 158.31, Turnover: 0.21
# Date: 2025-04-01 00:00:00, Capital: 159.72, Turnover: 0.20
# Date: 2025-04-02 00:00:00, Capital: 160.32, Turnover: 0.15
# Date: 2025-04-03 00:00:00, Capital: 160.14, Turnover: 0.04
# Date: 2025-04-04 00:00:00, Capital: 159.61, Turnover: 0.44
# Date: 2025-04-05 00:00:00, Capital: 161.01, Turnover: 1.32
# Date: 2025-04-08 00:00:00, Capital: 160.42, Turnover: 0.66
# Date: 2025-04-09 00:00:00, Capital: 157.82, Turnover: 1.82
# Date: 2025-04-10 00:00:00, Capital: 159.90, Turnover: 0.95
# Date: 2025-04-11 00:00:00, Capital: 160.79, Turnover: 0.60
# Date: 2025-04-12 00:00:00, Capital: 162.28, Turnover: 0.63
# Date: 2025-04-15 00:00:00, Capital: 158.68, Turnover: 0.84
# Date: 2025-04-16 00:00:00, Capital: 160.30, Turnover: 0.66
# Date: 2025-04-17 00:00:00, Capital: 163.54, Turnover: 0.06
# Date: 2025-04-18 00:00:00, Capital: 162.75, Turnover: 0.04
# Date: 2025-04-23 00:00:00, Capital: 165.52, Turnover: 0.18
# Date: 2025-04-24 00:00:00, Capital: 158.40, Turnover: 0.01
# Date: 2025-04-25 00:00:00, Capital: 159.61, Turnover: 0.09
# Date: 2025-04-26 00:00:00, Capital: 159.73, Turnover: 0.65
# Date: 2025-04-29 00:00:00, Capital: 161.46, Turnover: 0.67
# Date: 2025-04-30 00:00:00, Capital: 161.52, Turnover: 0.48
# Date: 2025-05-01 00:00:00, Capital: 161.92, Turnover: 0.77
# Date: 2025-05-02 00:00:00, Capital: 162.14, Turnover: 0.61
# Date: 2025-05-03 00:00:00, Capital: 164.05, Turnover: 0.02
# Date: 2025-05-06 00:00:00, Capital: 163.29, Turnover: 0.07
# Date: 2025-05-07 00:00:00, Capital: 161.39, Turnover: 0.10
# Date: 2025-05-08 00:00:00, Capital: 157.06, Turnover: 0.01
# Date: 2025-05-09 00:00:00, Capital: 152.38, Turnover: 0.08
# Date: 2025-05-10 00:00:00, Capital: 152.87, Turnover: 0.05
# Date: 2025-05-13 00:00:00, Capital: 147.26, Turnover: 0.11
# Date: 2025-05-14 00:00:00, Capital: 145.95, Turnover: 0.29
# Date: 2025-05-15 00:00:00, Capital: 152.17, Turnover: 0.16
# Date: 2025-05-16 00:00:00, Capital: 148.30, Turnover: 0.28
# Date: 2025-05-17 00:00:00, Capital: 155.26, Turnover: 0.29
# Date: 2025-05-20 00:00:00, Capital: 150.99, Turnover: 0.08
# Date: 2025-05-21 00:00:00, Capital: 148.63, Turnover: 0.01
# Date: 2025-05-22 00:00:00, Capital: 137.33, Turnover: 0.09
# Date: 2025-05-23 00:00:00, Capital: 143.57, Turnover: 0.17
# Date: 2025-05-24 00:00:00, Capital: 136.39, Turnover: 0.11
# Date: 2025-05-28 00:00:00, Capital: 124.67, Turnover: 0.22
# Date: 2025-05-29 00:00:00, Capital: 135.75, Turnover: 0.05
# Date: 2025-05-30 00:00:00, Capital: 122.07, Turnover: 0.02
# Date: 2025-05-31 00:00:00, Capital: 130.07, Turnover: 0.00
# Date: 2025-06-03 00:00:00, Capital: 121.78, Turnover: 0.10
# Date: 2025-06-04 00:00:00, Capital: 124.45, Turnover: 0.04
# Date: 2025-06-05 00:00:00, Capital: 118.79, Turnover: 0.00
# Date: 2025-06-06 00:00:00, Capital: 114.13, Turnover: 0.06
# Date: 2025-06-07 00:00:00, Capital: 124.13, Turnover: 0.02
# Date: 2025-06-10 00:00:00, Capital: 123.71, Turnover: 0.17
# Date: 2025-06-11 00:00:00, Capital: 134.47, Turnover: 0.01
# Date: 2025-06-12 00:00:00, Capital: 128.70, Turnover: 0.01
# Date: 2025-06-13 00:00:00, Capital: 134.52, Turnover: 0.03
# Date: 2025-06-14 00:00:00, Capital: 131.48, Turnover: 0.04
# Date: 2025-06-17 00:00:00, Capital: 126.26, Turnover: 0.08
# Date: 2025-06-18 00:00:00, Capital: 128.83, Turnover: 0.17
# Date: 2025-06-19 00:00:00, Capital: 127.46, Turnover: 0.20
# Date: 2025-06-21 00:00:00, Capital: 138.11, Turnover: 0.14
# Date: 2025-06-24 00:00:00, Capital: 136.71, Turnover: 0.09
# Date: 2025-06-25 00:00:00, Capital: 140.90, Turnover: 0.06
# Date: 2025-06-26 00:00:00, Capital: 143.47, Turnover: 0.14
# Date: 2025-06-27 00:00:00, Capital: 141.60, Turnover: 0.10
# Date: 2025-06-28 00:00:00, Capital: 147.16, Turnover: 0.02
# Date: 2025-07-01 00:00:00, Capital: 144.05, Turnover: 0.00
# Date: 2025-07-02 00:00:00, Capital: 145.75, Turnover: 0.17
# Date: 2025-07-03 00:00:00, Capital: 150.43, Turnover: 0.55
# Date: 2025-07-04 00:00:00, Capital: 150.03, Turnover: 0.06
# Date: 2025-07-08 00:00:00, Capital: 143.80, Turnover: 0.01
# Date: 2025-07-09 00:00:00, Capital: 148.28, Turnover: 0.37
# Date: 2025-07-10 00:00:00, Capital: 149.44, Turnover: 0.15
# Date: 2025-07-11 00:00:00, Capital: 149.49, Turnover: 0.06
# Date: 2025-07-12 00:00:00, Capital: 151.38, Turnover: 0.31
# Date: 2025-07-15 00:00:00, Capital: 148.69, Turnover: 0.45
# Date: 2025-07-16 00:00:00, Capital: 153.50, Turnover: 0.50
# Date: 2025-07-17 00:00:00, Capital: 150.02, Turnover: 0.48
# Date: 2025-07-18 00:00:00, Capital: 146.30, Turnover: 0.08
# Date: 2025-07-19 00:00:00, Capital: 147.45, Turnover: 0.19
# Date: 2025-07-22 00:00:00, Capital: 148.57, Turnover: 0.05
# Date: 2025-07-23 00:00:00, Capital: 147.94, Turnover: 0.12
# Date: 2025-07-24 00:00:00, Capital: 148.89, Turnover: 0.29
# Date: 2025-07-25 00:00:00, Capital: 148.96, Turnover: 0.93
# Date: 2025-07-26 00:00:00, Capital: 150.27, Turnover: 0.61
# Date: 2025-07-29 00:00:00, Capital: 147.57, Turnover: 0.77
# Date: 2025-07-30 00:00:00, Capital: 145.29, Turnover: 0.38
# Date: 2025-07-31 00:00:00, Capital: 145.93, Turnover: 0.80
# Date: 2025-08-01 00:00:00, Capital: 147.31, Turnover: 0.54
# Date: 2025-08-02 00:00:00, Capital: 151.21, Turnover: 0.69
# Date: 2025-08-05 00:00:00, Capital: 150.46, Turnover: 0.81
# Date: 2025-08-06 00:00:00, Capital: 153.13, Turnover: 0.60
# Date: 2025-08-07 00:00:00, Capital: 151.74, Turnover: 0.28
# Date: 2025-08-08 00:00:00, Capital: 151.82, Turnover: 0.75
# Date: 2025-08-09 00:00:00, Capital: 154.02, Turnover: 0.76
# Date: 2025-08-12 00:00:00, Capital: 156.40, Turnover: 0.96
# Date: 2025-08-13 00:00:00, Capital: 157.19, Turnover: 0.46
# Date: 2025-08-14 00:00:00, Capital: 159.59, Turnover: 0.31
# Date: 2025-08-15 00:00:00, Capital: 159.45, Turnover: 0.31
# Date: 2025-08-16 00:00:00, Capital: 160.69, Turnover: 0.39
# Date: 2025-08-19 00:00:00, Capital: 164.57, Turnover: 0.66
# Date: 2025-08-20 00:00:00, Capital: 164.94, Turnover: 0.17
# Date: 2025-08-21 00:00:00, Capital: 168.88, Turnover: 0.16
# Date: 2025-08-22 00:00:00, Capital: 169.98, Turnover: 0.70
# Date: 2025-08-23 00:00:00, Capital: 167.95, Turnover: 0.59
# Date: 2025-08-26 00:00:00, Capital: 167.83, Turnover: 0.33
# Date: 2025-08-27 00:00:00, Capital: 157.00, Turnover: 0.44
# Date: 2025-08-28 00:00:00, Capital: 159.28, Turnover: 0.28
# Date: 2025-08-29 00:00:00, Capital: 159.36, Turnover: 0.39
# Date: 2025-08-30 00:00:00, Capital: 162.52, Turnover: 0.54
# Date: 2025-09-03 00:00:00, Capital: 162.06, Turnover: 0.31
# Date: 2025-09-04 00:00:00, Capital: 161.59, Turnover: 0.23
# Date: 2025-09-06 00:00:00, Capital: 163.04, Turnover: 0.64
# Date: 2025-09-09 00:00:00, Capital: 165.16, Turnover: 0.60
# Date: 2025-09-10 00:00:00, Capital: 165.79, Turnover: 1.53
# Date: 2025-09-11 00:00:00, Capital: 162.29, Turnover: 1.20
# Date: 2025-09-12 00:00:00, Capital: 163.47, Turnover: 1.95
# Date: 2025-09-13 00:00:00, Capital: 160.05, Turnover: 0.31
# Date: 2025-09-16 00:00:00, Capital: 161.43, Turnover: 0.30
# Date: 2025-09-17 00:00:00, Capital: 164.45, Turnover: 0.04
# Date: 2025-09-18 00:00:00, Capital: 163.58, Turnover: 0.14
# Date: 2025-09-19 00:00:00, Capital: 164.91, Turnover: 0.30
# Date: 2025-09-20 00:00:00, Capital: 166.80, Turnover: 0.66
# Date: 2025-09-23 00:00:00, Capital: 164.06, Turnover: 0.18
# Date: 2025-09-24 00:00:00, Capital: 165.57, Turnover: 0.46
# Date: 2025-09-25 00:00:00, Capital: 166.08, Turnover: 1.03
# Date: 2025-09-26 00:00:00, Capital: 165.06, Turnover: 0.90
# Date: 2025-09-27 00:00:00, Capital: 162.52, Turnover: 0.28
# Date: 2025-09-30 00:00:00, Capital: 164.51, Turnover: 0.07
# Date: 2025-10-01 00:00:00, Capital: 165.89, Turnover: 0.32
# Date: 2025-10-02 00:00:00, Capital: 164.65, Turnover: 0.24
# Date: 2025-10-03 00:00:00, Capital: 165.85, Turnover: 0.20
# Date: 2025-10-04 00:00:00, Capital: 169.55, Turnover: 0.29
# Date: 2025-10-07 00:00:00, Capital: 168.68, Turnover: 0.21
# Date: 2025-10-08 00:00:00, Capital: 170.02, Turnover: 0.30
# Date: 2025-10-09 00:00:00, Capital: 168.95, Turnover: 0.86
# Date: 2025-10-10 00:00:00, Capital: 166.80, Turnover: 0.83
# Date: 2025-10-11 00:00:00, Capital: 169.16, Turnover: 0.51
# Date: 2025-10-14 00:00:00, Capital: 166.77, Turnover: 0.34
# Date: 2025-10-15 00:00:00, Capital: 169.40, Turnover: 1.39
# Date: 2025-10-16 00:00:00, Capital: 168.40, Turnover: 1.38
# Date: 2025-10-17 00:00:00, Capital: 169.20, Turnover: 0.96
# Date: 2025-10-18 00:00:00, Capital: 169.64, Turnover: 0.92
# Date: 2025-10-21 00:00:00, Capital: 167.10, Turnover: 2.00
# Date: 2025-10-22 00:00:00, Capital: 167.42, Turnover: 1.34
# Date: 2025-10-23 00:00:00, Capital: 168.60, Turnover: 0.71
# Date: 2025-10-24 00:00:00, Capital: 169.18, Turnover: 0.75
# Date: 2025-10-25 00:00:00, Capital: 167.01, Turnover: 0.43
# Date: 2025-10-28 00:00:00, Capital: 164.54, Turnover: 0.19
# Date: 2025-10-29 00:00:00, Capital: 167.42, Turnover: 0.36
# Date: 2025-10-30 00:00:00, Capital: 168.28, Turnover: 0.29
# Date: 2025-10-31 00:00:00, Capital: 166.61, Turnover: 0.39
# Date: 2025-11-01 00:00:00, Capital: 166.98, Turnover: 0.38
# Date: 2025-11-04 00:00:00, Capital: 166.97, Turnover: 0.64
# Date: 2025-11-05 00:00:00, Capital: 166.23, Turnover: 0.84
# Date: 2025-11-06 00:00:00, Capital: 166.57, Turnover: 0.65
# Date: 2025-11-07 00:00:00, Capital: 166.56, Turnover: 0.27
# Date: 2025-11-08 00:00:00, Capital: 167.89, Turnover: 0.33
# Date: 2025-11-11 00:00:00, Capital: 167.77, Turnover: 0.61
# Date: 2025-11-12 00:00:00, Capital: 169.54, Turnover: 0.64
# Date: 2025-11-13 00:00:00, Capital: 170.22, Turnover: 0.10
# Date: 2025-11-14 00:00:00, Capital: 171.45, Turnover: 0.16
# Date: 2025-11-15 00:00:00, Capital: 171.03, Turnover: 0.26
# Date: 2025-11-18 00:00:00, Capital: 172.50, Turnover: 0.36
# Date: 2025-11-19 00:00:00, Capital: 175.10, Turnover: 0.52
# Date: 2025-11-20 00:00:00, Capital: 166.91, Turnover: 0.78
# Date: 2025-11-21 00:00:00, Capital: 164.76, Turnover: 0.40
# Date: 2025-11-22 00:00:00, Capital: 158.45, Turnover: 0.52
# Date: 2025-11-25 00:00:00, Capital: 160.89, Turnover: 0.47
# Date: 2025-11-26 00:00:00, Capital: 157.82, Turnover: 0.73
# Date: 2025-11-27 00:00:00, Capital: 158.14, Turnover: 0.07
# Date: 2025-11-29 00:00:00, Capital: 160.58, Turnover: 0.15
# Date: 2025-12-02 00:00:00, Capital: 162.36, Turnover: 0.21
# Date: 2025-12-03 00:00:00, Capital: 161.25, Turnover: 0.11
# Date: 2025-12-04 00:00:00, Capital: 160.69, Turnover: 0.05
# Date: 2025-12-05 00:00:00, Capital: 158.84, Turnover: 0.09
# Date: 2025-12-06 00:00:00, Capital: 157.41, Turnover: 0.08
# Date: 2025-12-09 00:00:00, Capital: 159.80, Turnover: 0.06
# Date: 2025-12-10 00:00:00, Capital: 155.77, Turnover: 0.13
# Date: 2025-12-11 00:00:00, Capital: 156.57, Turnover: 0.33
# Date: 2025-12-12 00:00:00, Capital: 159.60, Turnover: 0.34
# Date: 2025-12-13 00:00:00, Capital: 161.13, Turnover: 0.15
# Date: 2025-12-16 00:00:00, Capital: 161.36, Turnover: 0.64
# Date: 2025-12-17 00:00:00, Capital: 162.01, Turnover: 0.65
# Date: 2025-12-18 00:00:00, Capital: 162.50, Turnover: 0.67
# Date: 2025-12-19 00:00:00, Capital: 160.12, Turnover: 0.25
# Date: 2025-12-20 00:00:00, Capital: 163.24, Turnover: 0.26
# Date: 2025-12-23 00:00:00, Capital: 161.77, Turnover: 0.35
# Date: 2025-12-24 00:00:00, Capital: 164.52, Turnover: 0.08
# Date: 2025-12-25 00:00:00, Capital: 165.65, Turnover: 0.03
# Date: 2025-12-27 00:00:00, Capital: 168.06, Turnover: 0.00
# Date: 2025-12-30 00:00:00, Capital: 171.61, Turnover: 0.02
# Date: 2025-12-31 00:00:00, Capital: 170.37, Turnover: 0.01
# Date: 2026-01-01 00:00:00, Capital: 170.55, Turnover: 0.10
# Date: 2026-01-03 00:00:00, Capital: 170.71, Turnover: 0.07
# Date: 2026-01-06 00:00:00, Capital: 170.24, Turnover: 0.45
# Date: 2026-01-07 00:00:00, Capital: 167.73, Turnover: 0.21
# Date: 2026-01-08 00:00:00, Capital: 167.81, Turnover: 0.39
# Date: 2026-01-09 00:00:00, Capital: 167.65, Turnover: 0.62
# Date: 2026-01-10 00:00:00, Capital: 167.40, Turnover: 0.52
# Date: 2026-01-13 00:00:00, Capital: 168.63, Turnover: 0.85
# Date: 2026-01-14 00:00:00, Capital: 164.90, Turnover: 0.38
# Date: 2026-01-15 00:00:00, Capital: 166.06, Turnover: 0.72
# Date: 2026-01-16 00:00:00, Capital: 159.23, Turnover: 0.29

# %%
plt.plot(dates[35:], conservative, c="green")
plt.plot(dates[35:], snp_values, c="red")
plt.plot(dates[35:], nasdaq_values, c="blue")
plt.xlabel("Date")
plt.ylabel("Portfolio Value")

plt.legend(["LASSSO", "S&P 500", "NASDAQ"])

plt.xticks(rotation=45)

plt.show()

# %%
def cagr(portfolio_values, periods_per_year=252):
    '''
    Calculate the Compound Annual Growth Rate (CAGR) of a portfolio.
    portfolio_values: list or np.array of portfolio values over time
    periods_per_year: number of periods in a year (e.g., 252 for daily data)
    returns: CAGR value
    '''
    years = len(portfolio_values) / periods_per_year
    cagr_value = (portfolio_values[-1] / portfolio_values[0]) ** (1 / years) - 1
    return 100*cagr_value

# %%
def volatility(portfolio_values, periods_per_year=252):
    '''
    Calculate the annualized volatility of a portfolio.
    portfolio_values: list or np.array of portfolio values over time
    periods_per_year: number of periods in a year (e.g., 252 for daily data)
    returns: annualized volatility value
    '''
    return 100*np.std(portfolio_values[1:] / portfolio_values[:-1] - 1) * np.sqrt(periods_per_year)

# %%
def sharpe_ratio(portfolio_values):
    '''
    Calculate the Sharpe Ratio of a portfolio.
    portfolio_values: list or np.array of portfolio values over time
    returns: Sharpe Ratio value
    '''
    return cagr(portfolio_values) / volatility(portfolio_values)

# %%
print(f"CAGR: {cagr(conservative):.2f} %")
print(f"Volatility: {volatility(conservative):.2f} %")
print(f"Sharpe Ratio: {sharpe_ratio(conservative):.2f}")
# Out:
# CAGR: 16.88 %
# Volatility: 25.53 %
# Sharpe Ratio: 0.66

# %%
print(f"CAGR: {cagr(snp_values):.2f} %")
print(f"Volatility: {volatility(snp_values):.2f} %")
print(f"Sharpe Ratio: {sharpe_ratio(snp_values):.2f}")
# Out:
# CAGR: 8.35 %
# Volatility: 23.10 %
# Sharpe Ratio: 0.36

# %%
print(f"CAGR: {cagr(nasdaq_values):.2f} %")
print(f"Volatility: {volatility(nasdaq_values):.2f} %")
print(f"Sharpe Ratio: {sharpe_ratio(nasdaq_values):.2f}")
# Out:
# CAGR: 18.51 %
# Volatility: 25.15 %
# Sharpe Ratio: 0.74
